# %%
from googleapiclient.discovery import build
import pandas as pd

API_KEY = "AIzaSyCkgvJOjlRJRY_zg1RAp5etEnMBhFTA2SA"
youtube = build('youtube', 'v3', developerKey=API_KEY)

request = youtube.search().list(
    q="artificial intelligence",
    part="snippet",
    type="video",
    maxResults=10
)
response = request.execute()

videos = []

for item in response['items']:
    video_id = item['id']['videoId']

    stats_request = youtube.videos().list(
        part="statistics",
        id=video_id
    )
    stats_response = stats_request.execute()

    stats = stats_response['items'][0]['statistics']

    videos.append({
        "title": item['snippet']['title'],
        "channel": item['snippet']['channelTitle'],
        "published_at": item['snippet']['publishedAt'],
        "views": stats.get('viewCount', 0),
        "likes": stats.get('likeCount', 0),
        "comments": stats.get('commentCount', 0)
    })

df = pd.DataFrame(videos)
df.to_csv("youtube_raw_data.csv", index=False)

# %%
df = pd.read_csv("youtube_raw_data.csv")

df.drop_duplicates(inplace=True)
df.fillna(0, inplace=True)

df['views'] = df['views'].astype(int)
df['likes'] = df['likes'].astype(int)
df['comments'] = df['comments'].astype(int)

df.to_csv("youtube_cleaned_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipython-input-2217186186.py in <cell line: 0>()
#       5 collection = db["youtube_videos"]
#       6
# ----> 7 print(collection.find_one())
#       8
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in find_one(self, filter, *args, **kwargs)
#    1753             filter = {"_id": filter}
#    1754         cursor = self.find(filter, *args, **kwargs)
# -> 1755         for result in cursor.limit(-1):
#    1756             return result
#    1757         return None
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1287
#    1288     def __next__(self) -> _DocumentType:
# -> 1289         return self.next()
#    1290
#    1291     def __iter__(self) -> Cursor[_DocumentType]:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in next(self)
#    1263         if self._empty:
#    1264             raise StopIteration
# -> 1265         if len(self._data) or self._refresh():
#    1266             return self._data.popleft()
#    1267         else:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _refresh(self)
#    1211                 self._exhaust,
#    1212             )
# -> 1213             self._send_message(q)
#    1214         elif self._id:  # Get More
#    1215             if self._limit:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _send_message(self, operation)
#    1106
#    1107         try:
# -> 1108             response = client._run_operation(
#    1109                 operation, self._unpack_response, address=self._address
#    1110             )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1936             )
#    1937
# -> 1938         return self._retryable_read(
#    1939             _cmd,
#    1940             operation.read_preference,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2046         )
#    2047         with self._tmp_session(session) as s:
# -> 2048             return self._retry_internal(
#    2049                 func,
#    2050                 s,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2761             self._check_last_error(check_csot=True)
#    2762             try:
# -> 2763                 return self._read() if self._is_read else self._write()
#    2764             except ServerSelectionTimeoutError:
#    2765                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    2906         :return: Output for func()'s call
#    2907         """
# -> 2908         self._server = self._get_server()
#    2909         assert self._read_pref is not None, "Read Preference required on read calls"
#    2910         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2854         :return: Abstraction to connect to server
#    2855         """
# -> 2856         return self._client._select_server(
#    2857             self._server_selector,
#    2858             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832             else:
# -> 1833                 server = topology.select_server(
#    1834                     server_selector,
#    1835                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     426     ) -> Server:
#     427         """Like select_servers, but choose a random server if several match."""
# --> 428         server = self._select_server(
#     429             selector,
#     430             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     400         operation_id: Optional[int] = None,
#     401     ) -> Server:
# --> 402         servers = self.select_servers(
#     403             selector,
#     404             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     296
#     297         with self._lock:
# --> 298             server_descriptions = self._select_servers_loop(
#     299                 selector,
#     300                 server_timeout,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     357                         failure=self._error_message(selector),
#     358                     )
# --> 359                 raise ServerSelectionTimeoutError(
#     360                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361                 )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6970acb32541ba9664ba2c4b, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
print(df.head())
# Out:
#                                                title               channel  \
# 0  Microsoft CEO Nadella on How AI Can Change Wor...  Bloomberg Television
# 1                            Artificial Intelligence     Hardcor-e - Topic
# 2                            Artificial Intelligence     MIKE DEAN - Topic
# 3  Artificial Intelligence | 60 Minutes Full Epis...            60 Minutes
# 4  What Is AI? | Learn all about artificial intel...          Learn Bright
#
#            published_at    views  likes  comments
# 0  2026-01-20T10:36:18Z     9055    178        27
# 1  2016-08-25T01:35:19Z  1175773  21443         4
# 2  2023-04-29T04:01:20Z   751927  12141       195
# 3  2023-12-30T13:00:02Z  9230098  95854      8079
# 4  2024-12-05T16:00:26Z   359926   2782         0

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://127.0.0.1:27017/")
db = client["social_media_db"]
collection = db["youtube_videos"]

print(collection.find_one())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipython-input-3490001795.py in <cell line: 0>()
#       5 collection = db["youtube_videos"]
#       6
# ----> 7 print(collection.find_one())
#       8
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in find_one(self, filter, *args, **kwargs)
#    1753             filter = {"_id": filter}
#    1754         cursor = self.find(filter, *args, **kwargs)
# -> 1755         for result in cursor.limit(-1):
#    1756             return result
#    1757         return None
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1287
#    1288     def __next__(self) -> _DocumentType:
# -> 1289         return self.next()
#    1290
#    1291     def __iter__(self) -> Cursor[_DocumentType]:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in next(self)
#    1263         if self._empty:
#    1264             raise StopIteration
# -> 1265         if len(self._data) or self._refresh():
#    1266             return self._data.popleft()
#    1267         else:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _refresh(self)
#    1211                 self._exhaust,
#    1212             )
# -> 1213             self._send_message(q)
#    1214         elif self._id:  # Get More
#    1215             if self._limit:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _send_message(self, operation)
#    1106
#    1107         try:
# -> 1108             response = client._run_operation(
#    1109                 operation, self._unpack_response, address=self._address
#    1110             )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1936             )
#    1937
# -> 1938         return self._retryable_read(
#    1939             _cmd,
#    1940             operation.read_preference,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2046         )
#    2047         with self._tmp_session(session) as s:
# -> 2048             return self._retry_internal(
#    2049                 func,
#    2050                 s,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2761             self._check_last_error(check_csot=True)
#    2762             try:
# -> 2763                 return self._read() if self._is_read else self._write()
#    2764             except ServerSelectionTimeoutError:
#    2765                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    2906         :return: Output for func()'s call
#    2907         """
# -> 2908         self._server = self._get_server()
#    2909         assert self._read_pref is not None, "Read Preference required on read calls"
#    2910         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2854         :return: Abstraction to connect to server
#    2855         """
# -> 2856         return self._client._select_server(
#    2857             self._server_selector,
#    2858             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832             else:
# -> 1833                 server = topology.select_server(
#    1834                     server_selector,
#    1835                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     426     ) -> Server:
#     427         """Like select_servers, but choose a random server if several match."""
# --> 428         server = self._select_server(
#     429             selector,
#     430             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     400         operation_id: Optional[int] = None,
#     401     ) -> Server:
# --> 402         servers = self.select_servers(
#     403             selector,
#     404             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     296
#     297         with self._lock:
# --> 298             server_descriptions = self._select_servers_loop(
#     299                 selector,
#     300                 server_timeout,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     357                         failure=self._error_message(selector),
#     358                     )
# --> 359                 raise ServerSelectionTimeoutError(
#     360                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361                 )
#
# ServerSelectionTimeoutError: 127.0.0.1:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6970ad042541ba9664ba2c4c, topology_type: Unknown, servers: [<ServerDescription ('127.0.0.1', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('127.0.0.1:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://127.0.0.1:27017", serverSelectionTimeoutMS=5000)
db = client.test
print(db.command("ping"))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipython-input-1069103947.py in <cell line: 0>()
#       3 client = MongoClient("mongodb://127.0.0.1:27017", serverSelectionTimeoutMS=5000)
#       4 db = client.test
# ----> 5 print(db.command("ping"))
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/database.py in command(self, command, value, check, allowable_errors, read_preference, codec_options, session, comment, **kwargs)
#     932         if read_preference is None:
#     933             read_preference = (session and session._txn_read_preference()) or ReadPreference.PRIMARY
# --> 934         with self._client._conn_for_reads(read_preference, session, operation=command_name) as (
#     935             connection,
#     936             read_preference,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _conn_for_reads(self, read_preference, session, operation)
#    1883     ) -> ContextManager[tuple[Connection, _ServerMode]]:
#    1884         assert read_preference is not None, "read_preference must not be None"
# -> 1885         server = self._select_server(read_preference, session, operation)
#    1886         return self._conn_from_server(read_preference, server, session)
#    1887
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832             else:
# -> 1833                 server = topology.select_server(
#    1834                     server_selector,
#    1835                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     426     ) -> Server:
#     427         """Like select_servers, but choose a random server if several match."""
# --> 428         server = self._select_server(
#     429             selector,
#     430             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     400         operation_id: Optional[int] = None,
#     401     ) -> Server:
# --> 402         servers = self.select_servers(
#     403             selector,
#     404             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     296
#     297         with self._lock:
# --> 298             server_descriptions = self._select_servers_loop(
#     299                 selector,
#     300                 server_timeout,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     357                         failure=self._error_message(selector),
#     358                     )
# --> 359                 raise ServerSelectionTimeoutError(
#     360                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361                 )
#
# ServerSelectionTimeoutError: 127.0.0.1:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 5.0s, Topology Description: <TopologyDescription id: 6970ae162541ba9664ba2c4d, topology_type: Unknown, servers: [<ServerDescription ('127.0.0.1', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('127.0.0.1:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
